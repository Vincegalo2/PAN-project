# %% [markdown]
# # Music Industry

# %%
import pandas as pd
wikiurl = 'https://en.wikipedia.org/wiki/Music_industry'
tables = pd.read_html(wikiurl)

# %% [markdown]
# ### Album Sales and Market Value in the World in 2014.

# %%
albums_sales_2014_df = tables[2] #Music markets, with total retail value, and share of Physical, Digital records, 2014
albums_sales_2014_df
# Out:
#     Ranking          Market  Retail value US $ (millions) % Change Physical  \
# 0         1   United States                        4898.3     2.1%      26%
# 1         2           Japan                        2627.9    −5.5%      78%
# 2         3         Germany                        1404.8     1.9%      70%
# 3         4  United Kingdom                        1334.6    −2.8%      41%
# 4         5          France                         842.8    −3.4%      57%
# 5         6       Australia                         376.1    −6.8%      32%
# 6         7          Canada                         342.5   −11.3%      38%
# 7         8     South Korea                         265.8    19.2%      38%
# 8         9          Brazil                         246.5     2.0%      41%
# 9        10           Italy                         235.2     4.1%      51%
# 10       11     Netherlands                         204.8     2.1%      45%
# ...

# %% [markdown]
# ### Total Revenue by Year

# %%
revenue_yr_df = tables[4].drop(columns='Notes') #Global trade revenue according to the IFPI.
revenue_yr_df
# Out:
#     Year         Revenue  Change
# 0   2005   $20.7 billion     −3%
# 1   2006   $19.6 billion     −5%
# 2   2007   $18.8 billion     −4%
# 3   2008   $18.4 billion     −2%
# 4   2009   $17.4 billion     −5%
# 5   2010   $16.8 billion   −3.4%
# 6   2011   $16.2 billion     −4%
# 7   2012   $16.5 billion     +2%
# 8   2013     $15 billion     −9%
# 9   2014  $14.97 billion   −0.2%
# 10  2015     $15 billion   +3.2%
# 11  2016   $15.7 billion     +5%
# 12  2017   $17.4 billion  +10.8%
# 13  2018   $19.1 billion   +9.7%
# 14  2019   $20.2 billion   +8.2%
# 15  2020   $21.6 billion   +7.4%
# 16  2021   $25.9 billion  +18.5%
# 17  2022   $26.2 billion     +9%
